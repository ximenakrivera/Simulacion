# %% [markdown]
# <a href="https://colab.research.google.com/github/ximenakrivera/Simulacion/blob/main/Unidad2/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Parámetros del método de congruencia lineal
a = 1664525
 # Factor multiplicativo
c = 1013904223
# Incremento
m = 2**32
# Módulo

# Semilla inicial
semilla = 5738

# Número de iteraciones
iteraciones = 100

# Lista para almacenar los números generados
resultados = []

# Generación de números pseudoaleatorios
for _ in range(iteraciones):
    semilla = (a * semilla + c) % m
    resultados.append(semilla)

# Imprimir los resultados
for i, numero in enumerate(resultados, 1):
    print(f"Iteración {i}: {numero}")
# Out:
# Iteración 1: 1975014081
# Iteración 2: 3164409132
# Iteración 3: 2901681819
# Iteración 4: 291089214
# Iteración 5: 2437241221
# Iteración 6: 4238114080
# Iteración 7: 2723941887
# Iteración 8: 2257994578
# Iteración 9: 2212825737
# Iteración 10: 950276692
# Iteración 11: 1178950051
# Iteración 12: 815166118
# Iteración 13: 3623283149
# Iteración 14: 1780842696
# Iteración 15: 623783303
# Iteración 16: 4162456890
# Iteración 17: 2175843153
# Iteración 18: 2280897660
# Iteración 19: 2835672491
# Iteración 20: 4262733582
# Iteración 21: 4217537301
# Iteración 22: 230095216
# Iteración 23: 839663119
# Iteración 24: 3074364450
# Iteración 25: 2751104281
# Iteración 26: 1621142436
# Iteración 27: 3959358131
# Iteración 28: 384854134
# Iteración 29: 1674134877
# Iteración 30: 1163888408
# Iteración 31: 57958295
# Iteración 32: 489486346
# Iteración 33: 3682961377
# Iteración 34: 3679682508
# Iteración 35: 528726203
# Iteración 36: 1543296734
# Iteración 37: 2710589605
# ...
