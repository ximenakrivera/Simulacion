# %% [markdown]
# <a href="https://colab.research.google.com/github/ximenakrivera/Simulacion/blob/main/Unidad3/Problema_2_Distribuci%C3%B3n_Exponencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetro de la distribución exponencial (tasa de carga por coche)
lambda_carga = 1 / 15  # Tiempo promedio de carga = 15 minutos

# Función para generar un tiempo de inactividad
def generar_tiempo_carga(lambda_carga):
    u = np.random.uniform(0, 1)  # Generar número aleatorio uniforme
    # Aplicar transformada inversa
    tiempo_carga = -1 / lambda_carga * np.log(1 - u)
    return tiempo_carga

# Generar 12 horas de carga que es igual a 48 veces
tiempos_carga = [generar_tiempo_carga(lambda_carga)
                       for _ in range(48)]

# Mostrar los tiempos de carga generados
print("Tiempos de carga generados:", tiempos_carga)

# Graficar los tiempos de carga simulados
plt.hist(tiempos_carga, bins=10, edgecolor='black', alpha=0.7)
plt.title('Distribución de Tiempos de carga Simulados (Exponencial)')
plt.xlabel('Tiempo de carga (minutos)')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# Tiempos de carga generados: [np.float64(2.4875569204221897), np.float64(1.6749831918026779), np.float64(4.577440330981758), np.float64(3.6565848290451863), np.float64(27.4292913556721), np.float64(50.66640742670559), np.float64(21.485736317114593), np.float64(25.465499245569603), np.float64(1.817967517801236), np.float64(8.956261051155849), np.float64(14.589800063068662), np.float64(4.774425904812796), np.float64(3.5335250055452763), np.float64(2.885424093902253), np.float64(0.4156010569642647), np.float64(39.91286401493531), np.float64(25.697864584488617), np.float64(0.8010085459436003), np.float64(10.85145383160583), np.float64(6.921196638940756), np.float64(5.66483757825255), np.float64(25.942114831469368), np.float64(20.074245938627513), np.float64(5.09482584934094), np.float64(0.4206943248534106), np.float64(5.285325083756824), np.float64(6.594893695564827), np.float64(15.938864479661955), np.float64(33.5301355318635), np.float64(4.482232243209241), np.float64(17.448854330757893), np.float64(2.4854791177676248), np.float64(15.081472681552663), np.float64(5.461268485315111), np.float64(10.204820096059896), np.float64(71.3572102127017), np.float64(12.090772552917691), np.float64(34.74908784101045), np.float64(12.73511855121571), np.float64(7.692857648305119), np.float64(27.967644195200204), np.float64(4.251331863168168), np.float64(2.208529523829606), np.float64(6.532359875596956), np.float64(0.9988511797459023), np.float64(34.139659175403175), np.float64(27.54058745198053), np.float64(2.5506728923167756)]
